# %%
# 2. 필요한 모듈 임포트
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
from IPython.display import display

from services.data_preparer import prepare_proposal_09_data
from services.proposal_views.proposal_09_view import create_figure_and_df

# --- 테스트 실행 ---

# 1. app.py의 역할 (1): 데이터 준비 함수를 호출하여 필요한 데이터를 미리 로드합니다.
print("Step 1: `data_preparer`를 통해 분석용 데이터와 순서 정보를 준비합니다...")
data_bundle = prepare_proposal_09_data() # 글로벌 필터는 모두 기본값('전체')으로 호출
order_map = data_bundle.get("order_map", {})
print(" -> 데이터 준비 완료!")


# 2. app.py의 역할 (2): 사용자가 Streamlit 위젯을 통해 필터를 선택했다고 가정합니다.

# 2-1. app.py에 있을 차원 설정(Dimension Config) 정의
DIMENSION_CONFIG = {
    '부서별': {'type': 'hierarchical', 'top': 'DIVISION_NAME', 'sub': 'OFFICE_NAME'},
    '직무별': {'type': 'hierarchical', 'top': 'JOB_L1_NAME', 'sub': 'JOB_L2_NAME'},
    '직위직급별': {'type': 'flat', 'col': 'POSITION_NAME'},
    '성별': {'type': 'flat', 'col': 'GENDER'},
    '연령별': {'type': 'flat', 'col': 'AGE_BIN'},
    '경력연차별': {'type': 'flat', 'col': 'CAREER_BIN'},
    '연봉구간별': {'type': 'flat', 'col': 'SALARY_BIN'},
    '지역별': {'type': 'flat', 'col': 'REGION_CATEGORY'},
    '계약별': {'type': 'flat', 'col': 'CONT_CATEGORY'}
}

# 2-2. 사용자 선택 시뮬레이션
# ----- 테스트하고 싶은 값으로 변경 -----
selected_dimension_ui = '연령별'
# 이 뷰는 드릴다운 기능이 없으므로, drilldown_selection은 항상 '전체' 입니다.
drilldown_selection = '전체'
# -----------------------------------

print(f"Step 2: 사용자가 '{selected_dimension_ui}' 차원을 선택했습니다.")


# 3. app.py의 역할 (3): view 함수에 준비된 모든 데이터와 필터 값을 전달하여 결과물 생성
print("Step 3: `view` 모듈을 호출하여 그래프와 요약 테이블을 생성합니다...")
if data_bundle.get("analysis_df") is not None and not data_bundle["analysis_df"].empty:
    fig, aggregate_df = create_figure_and_df(
        data_bundle=data_bundle, 
        dimension_ui_name=selected_dimension_ui, 
        #drilldown_selection=drilldown_selection, # 이 뷰에서는 사용되지 않지만 일관성을 위해 전달
        dimension_config=DIMENSION_CONFIG,
        order_map=order_map
    )
    print(" -> 생성 완료!")
else:
    print(" -> 분석할 데이터가 없어 빈 결과물을 생성합니다.")
    fig, aggregate_df = go.Figure(), pd.DataFrame()


# --- 결과 확인 ---

# 4. ipynb에서 생성된 그래프를 확인합니다.
print("\n--- [결과 1] 생성된 Plotly 그래프 ---")
# pio.renderers.default = 'vscode' 
fig.show()

# 5. ipynb에서 생성된 요약 테이블(aggregate_df)을 확인합니다.
print(f"\n--- [결과 2] '{selected_dimension_ui}' 기준 생성된 요약 테이블 ---")
display(aggregate_df)
# Out:
# Step 1: `data_preparer`를 통해 분석용 데이터와 순서 정보를 준비합니다...
#  -> 데이터 준비 완료!
# Step 2: 사용자가 '연령별' 차원을 선택했습니다.
# Step 3: `view` 모듈을 호출하여 그래프와 요약 테이블을 생성합니다...
#  -> 생성 완료!
#
# --- [결과 1] 생성된 Plotly 그래프 ---
# --- [결과 2] '연령별' 기준 생성된 요약 테이블 ---
# GROUP_NAME  전체 평균  20세 미만  20-29세  30-39세  40-49세  50세 이상
# YEAR
# 2013         2.45     0.0    4.88    3.03    0.00     0.0
# 2014         1.21     0.0    0.00    1.63    1.33     0.0
# 2015         1.65     0.0    1.67    1.26    2.38     0.0
# 2016         2.69     0.0    0.00    5.06    0.00     0.0
# 2017         4.36     0.0    4.29    5.24    2.83     0.0
# 2018         5.32     0.0    3.57    5.56    6.19     0.0
# 2019         7.19     0.0    5.43    5.61   11.20     0.0
# 2020         5.05     0.0    4.35    7.11    2.17     0.0
# 2021         5.35     0.0    3.88    5.86    5.63     0.0
# 2022         9.78     0.0   10.38    8.90   10.74     0.0
# 2023         6.55     0.0    7.02    6.25    6.67     0.0
# 2024         7.18     0.0    4.92    8.82    6.45     0.0
# 2025         6.04     0.0    7.83    5.94    4.79     0.0

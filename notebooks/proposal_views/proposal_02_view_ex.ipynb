# %%
# 2. 필요한 모듈 임포트
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
from IPython.display import display

#    - 데이터 준비를 담당하는 preparer 함수
from services.data_preparer import prepare_proposal_02_data
#    - 시각화를 담당하는 view 함수
from services.proposal_views.proposal_02_view import create_figure

# --- 테스트 실행 ---

# 1. app.py의 역할 (1): 데이터 준비 함수를 호출하여 필요한 모든 데이터를 미리 로드합니다.
# 글로벌 필터는 모두 기본값('전체')으로 호출합니다.
print("Step 1: `data_preparer`를 통해 생키 다이어그램 데이터를 준비합니다...")
data_bundle = prepare_proposal_02_data()
print(" -> 데이터 준비 완료!")


# 2. app.py의 역할 (2): view 함수에 준비된 데이터를 전달하여 결과물 생성
# 이 view는 자체적으로 드롭다운 메뉴를 가지고 있으므로, 별도의 필터 선택 시뮬레이션이 필요 없습니다.
print("Step 2: `view` 모듈을 호출하여 그래프를 생성합니다...")
if data_bundle:
    fig, _ = create_figure(
        data_bundle=data_bundle
    )
    print(" -> 생성 완료!")
else:
    print(" -> 분석할 데이터가 없어 빈 그래프를 생성합니다.")
    fig = go.Figure()


# --- 결과 확인 ---

# 3. ipynb에서 생성된 그래프를 확인합니다.
print("\n--- [결과] 생성된 Plotly 그래프 ---")
# pio.renderers.default = 'vscode' 
fig.show()

# 4. (참고) data_bundle의 내용 확인
#    어떤 데이터가 view로 전달되는지 확인하고 싶을 때 주석을 해제하세요.
# print("\n--- [참고] data_bundle 내용 ---")
# if data_bundle:
#     print("--- Division Sankey Data ---")
#     display(data_bundle["sankey_div_data"]["data"])
#     print("\n--- Job Sankey Data ---")
#     display(data_bundle["sankey_job_data"]["data"])
# Out:
# /app/src/services/tables/Time_Attendance/detailed_working_info_table.py:79: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['IS_VACATION'] = df['IS_VACATION'].fillna(False).astype(bool)
# 2025-10-10 07:11:35.240 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-10 07:11:35.247 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-10 07:11:35.256 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-10 07:11:35.258 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# ...

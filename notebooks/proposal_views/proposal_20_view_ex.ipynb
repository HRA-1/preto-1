# %%
# 2. 필요한 모듈 임포트
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
from IPython.display import display

from services.data_preparer import prepare_proposal_20_data
from services.proposal_views.proposal_20_view import create_figure_and_df

# --- 테스트 실행 ---

# 1. app.py의 역할 (1): 데이터 준비 함수를 호출하여 필요한 데이터를 미리 로드합니다.
print("Step 1: `data_preparer`를 통해 분석용 데이터와 순서 정보를 준비합니다...")
# 글로벌 필터는 모두 기본값('전체')으로 호출
data_bundle = prepare_proposal_20_data() 
analysis_df = data_bundle.get("analysis_df", pd.DataFrame())
order_map = data_bundle.get("order_map", {})
print(" -> 데이터 준비 완료!")


# 2. app.py의 역할 (2): 사용자가 Streamlit 위젯을 통해 필터를 선택했다고 가정합니다.

# 2-1. app.py에 있을 차원 설정(Dimension Config) 정의
DIMENSION_CONFIG = {
    '부서별': {'type': 'hierarchical', 'top': 'DIVISION_NAME', 'sub': 'OFFICE_NAME'},
    '직무별': {'type': 'hierarchical', 'top': 'JOB_L1_NAME', 'sub': 'JOB_L2_NAME'},
    '직위직급별': {'type': 'flat', 'col': 'POSITION_NAME'},
    '성별': {'type': 'flat', 'col': 'GENDER'},
    '연령별': {'type': 'flat', 'col': 'AGE_BIN'},
    '경력연차별': {'type': 'flat', 'col': 'CAREER_BIN'},
    '연봉구간별': {'type': 'flat', 'col': 'SALARY_BIN'},
    '지역별': {'type': 'flat', 'col': 'REGION_CATEGORY'},
    '계약별': {'type': 'flat', 'col': 'CONT_CATEGORY'}
}

# 2-2. 사용자 선택 시뮬레이션
# ----- 테스트하고 싶은 값으로 변경 -----
selected_dimension_ui = '부서별'
# 이 뷰는 드릴다운 기능이 없으므로, drilldown_selection은 '전체'로 고정
drilldown_selection = '전체'
# -----------------------------------

print(f"Step 2: 사용자가 '{selected_dimension_ui}' 차원을 선택했습니다.")


# 3. app.py의 역할 (3): view 함수에 준비된 모든 데이터와 필터 값을 전달하여 결과물 생성
print("Step 3: `view` 모듈을 호출하여 그래프와 요약 테이블을 생성합니다...")
if not analysis_df.empty:
    fig, aggregate_df = create_figure_and_df(
        analysis_df=analysis_df, 
        dimension_ui_name=selected_dimension_ui, 
        # drilldown_selection=drilldown_selection, # 이 뷰는 '전체'일 때만 작동
        dimension_config=DIMENSION_CONFIG,
        order_map=order_map
    )
    print(" -> 생성 완료!")
else:
    print(" -> 분석할 데이터가 없어 빈 결과물을 생성합니다.")
    fig, aggregate_df = go.Figure(), pd.DataFrame()


# --- 결과 확인 ---

# 4. ipynb에서 생성된 그래프를 확인합니다.
print("\n--- [결과 1] 생성된 Plotly 그래프 ---")
# pio.renderers.default = 'vscode' 
fig.show()

# 5. ipynb에서 생성된 요약 테이블(aggregate_df)을 확인합니다.
print(f"\n--- [결과 2] 생성된 요약 테이블 ---")
display(aggregate_df)
# Out:
# /app/src/services/tables/Time_Attendance/detailed_working_info_table.py:79: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['IS_VACATION'] = df['IS_VACATION'].fillna(False).astype(bool)
# 2025-10-21 08:42:32.962 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:32.972 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:32.979 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:32.986 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:32.991 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:32.994 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:32.997 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.001 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.005 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.007 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.010 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.014 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.017 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.021 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.025 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.029 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.033 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.037 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.041 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.044 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.047 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.049 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.051 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.055 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.059 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.111 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:33.111 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# Step 1: `data_preparer`를 통해 분석용 데이터와 순서 정보를 준비합니다...
# 2025-10-21 08:42:33.452
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-10-21 08:42:33.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-21 08:42:33.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-21 08:42:33.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-21 08:42:33.455 No runtime found, using MemoryCacheStorageManager
# 2025-10-21 08:42:34.194 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-21 08:42:34.211 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-21 08:42:34.374 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-21 08:42:38.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-21 08:42:38.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-21 08:42:38.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#  -> 데이터 준비 완료!
# Step 2: 사용자가 '부서별' 차원을 선택했습니다.
# Step 3: `view` 모듈을 호출하여 그래프와 요약 테이블을 생성합니다...
#  -> 생성 완료!
#
# --- [결과 1] 생성된 Plotly 그래프 ---
# --- [결과 2] 생성된 요약 테이블 ---
#                                         2020                        \
#                            BRIDGE_LEAVE_RATE LONG_LEAVE_RATE 팀 인원수
# TEAM_NAME
# APAC Sales Team                         39.3             2.9  16.0
# Accounting Team                         40.3             1.1  20.0
# Analysis Team                           38.4             0.0  20.0
# Backend Team                            42.9             0.0  16.0
# Content Marketing Team                  38.5             8.5  21.0
# Domestic Sales Office                   45.5             0.0  19.0
# Domestic Sales Team 1                   39.3             6.5  16.0
# Domestic Sales Team 2                   42.1             0.0  11.0
# EU/NA Sales Team                        44.4             0.0  25.0
# Engineering Office                      28.4             2.1  20.0
# Finance Office                          40.5             0.0  11.0
# Frontend Team                           42.3             0.0  22.0
# Global Sales Office                     41.9             0.0  19.0
# HR Team                                 41.3             0.0  14.0
# Marketing Office                        38.2             0.0  15.0
# Mobile Team                             37.8             6.1  22.0
# Performance Marketing Team              37.9             3.0  22.0
# Planning Team                           42.4             4.7  23.0
# Process Engineering Team                30.4             2.7  17.0
# Production Office                       28.1             0.0  18.0
# Production Team Alpha                   32.4             1.0  24.0
# Production Team Beta                    30.2             1.2  17.0
# Production Team Charlie                 26.0             2.1  21.0
# QA Office                               39.5             0.0  12.0
# Quality Engineering Team                27.4             7.0  22.0
# R&D Office                              36.1             1.1  20.0
# Service QA Team                         37.5             4.5  18.0
# Strategy Office                         38.1             2.1  25.0
# System QA Team                          36.9             9.0  16.0
# Treasury Team                           38.0            10.9  19.0
#
#                                         2021                        \
#                            BRIDGE_LEAVE_RATE LONG_LEAVE_RATE 팀 인원수
# TEAM_NAME
# APAC Sales Team                         41.1             0.0  18.0
# Accounting Team                         42.9             1.5  17.0
# Analysis Team                           39.2             3.6  24.0
# Backend Team                            41.8             6.7  16.0
# Content Marketing Team                  41.1             2.2  20.0
# Domestic Sales Office                   37.9             2.8  16.0
# Domestic Sales Team 1                   43.9             1.4  17.0
# Domestic Sales Team 2                   49.3             0.0  10.0
# EU/NA Sales Team                        41.0             4.4  25.0
# Engineering Office                      26.8             3.5  20.0
# Finance Office                          37.9             7.6  16.0
# Frontend Team                           39.9             0.9  25.0
# Global Sales Office                     44.4             0.0  14.0
# HR Team                                 46.1             1.4  15.0
# Marketing Office                        40.5             1.8  17.0
# Mobile Team                             39.8             0.0  19.0
# Performance Marketing Team              40.3             1.7  24.0
# Planning Team                           43.0             1.0  22.0
# Process Engineering Team                31.5             5.0  18.0
# Production Office                       28.4             0.0  18.0
# Production Team Alpha                   22.3             1.1  21.0
# Production Team Beta                    25.9             0.0  17.0
# Production Team Charlie                 32.2             0.0  21.0
# QA Office                               33.5             0.0  13.0
# Quality Engineering Team                28.6             1.9  23.0
# R&D Office                              40.4             1.4  23.0
# Service QA Team                         40.5             0.0  18.0
# Strategy Office                         42.4             3.4  27.0
# System QA Team                          46.2             0.0  20.0
# Treasury Team                           38.9             0.0  20.0
#
#                                         2022                        \
#                            BRIDGE_LEAVE_RATE LONG_LEAVE_RATE 팀 인원수
# TEAM_NAME
# APAC Sales Team                         44.8             8.5  19.0
# Accounting Team                         46.3             3.5  17.0
# Analysis Team                           38.4             2.0  22.0
# Backend Team                            38.8             0.0  17.0
# Content Marketing Team                  41.5             3.5  20.0
# Domestic Sales Office                   46.3             0.0  14.0
# Domestic Sales Team 1                   40.6             0.0  24.0
# Domestic Sales Team 2                   37.1             2.9  16.0
# EU/NA Sales Team                        38.1             0.0  25.0
# Engineering Office                      25.2             1.4  23.0
# Finance Office                          42.4             3.8  20.0
# Frontend Team                           34.5             0.0  17.0
# Global Sales Office                     37.8             9.3  13.0
# HR Team                                 38.7             0.0  16.0
# Marketing Office                        33.7             1.2  19.0
# Mobile Team                             43.4             1.1  21.0
# Performance Marketing Team              38.4             0.0  23.0
# Planning Team                           40.5             0.0  20.0
# Process Engineering Team                26.7             0.0  17.0
# Production Office                       25.9             4.8  20.0
# Production Team Alpha                   26.8             7.1  19.0
# Production Team Beta                    26.0             4.3  20.0
# Production Team Charlie                 30.3             5.5  26.0
# QA Office                               40.1             0.0  14.0
# Quality Engineering Team                25.8             3.2  21.0
# R&D Office                              37.9             0.0  22.0
# Service QA Team                         33.6             1.2  19.0
# Strategy Office                         41.7             0.9  26.0
# System QA Team                          37.4             3.1  22.0
# Treasury Team                           38.7            10.7  20.0
#
#                                         2023                        \
#                            BRIDGE_LEAVE_RATE LONG_LEAVE_RATE 팀 인원수
# TEAM_NAME
# APAC Sales Team                         38.8             1.2  19.0
# Accounting Team                         39.4             1.1  22.0
# Analysis Team                           40.4             1.6  26.0
# Backend Team                            41.5             1.9  19.0
# Content Marketing Team                  41.1             1.0  21.0
# Domestic Sales Office                   36.3             4.2  16.0
# Domestic Sales Team 1                   43.0             0.8  24.0
# Domestic Sales Team 2                   38.9             0.0  15.0
# EU/NA Sales Team                        41.9             6.7  26.0
# Engineering Office                      29.6             3.9  23.0
# Finance Office                          44.2             4.5  24.0
# Frontend Team                           46.3             2.5  19.0
# Global Sales Office                     33.8             1.4  18.0
# HR Team                                 44.3             4.5  20.0
# Marketing Office                        40.7             1.1  21.0
# Mobile Team                             40.3             3.5  21.0
# Performance Marketing Team              40.6             6.8  18.0
# Planning Team                           41.9             3.3  21.0
# Process Engineering Team                29.3             1.0  22.0
# Production Office                       31.5             3.9  24.0
# Production Team Alpha                   31.7             0.0  16.0
# Production Team Beta                    26.5             2.5  20.0
# Production Team Charlie                 28.2             3.9  26.0
# QA Office                               39.4             0.0  14.0
# Quality Engineering Team                31.9             1.1  21.0
# R&D Office                              40.1             3.9  22.0
# Service QA Team                         40.5             8.6  20.0
# Strategy Office                         42.4             2.5  24.0
# System QA Team                          42.5             1.0  22.0
# Treasury Team                           41.6             3.2  19.0
#
#                                         2024                        \
#                            BRIDGE_LEAVE_RATE LONG_LEAVE_RATE 팀 인원수
# TEAM_NAME
# APAC Sales Team                         37.1             2.9  24.0
# Accounting Team                         39.3             1.3  16.0
# Analysis Team                           40.8             0.9  27.0
# Backend Team                            41.8             2.4  20.0
# Content Marketing Team                  49.1             6.3  21.0
# Domestic Sales Office                   45.8             2.8  15.0
# Domestic Sales Team 1                   41.0             1.6  23.0
# Domestic Sales Team 2                   38.0             2.4  19.0
# EU/NA Sales Team                        37.4             0.8  26.0
# Engineering Office                      27.6             4.7  27.0
# Finance Office                          40.9             1.5  20.0
# Frontend Team                           46.0             3.1  21.0
# Global Sales Office                     35.8             0.0  20.0
# HR Team                                 39.9             5.8  21.0
# Marketing Office                        38.0             4.7  17.0
# Mobile Team                             37.3             0.0  23.0
# Performance Marketing Team              36.0             3.4  19.0
# Planning Team                           42.8             0.0  28.0
# Process Engineering Team                27.4             1.9  24.0
# Production Office                       29.4             5.0  25.0
# Production Team Alpha                   26.6             1.1  21.0
# Production Team Beta                    29.9             7.1  22.0
# Production Team Charlie                 26.9             0.0  20.0
# QA Office                               43.8             0.0  12.0
# Quality Engineering Team                26.9             2.1  20.0
# R&D Office                              39.6             2.2  19.0
# Service QA Team                         39.9             0.0  21.0
# Strategy Office                         35.5             4.7  26.0
# System QA Team                          41.8             7.0  28.0
# Treasury Team                           35.5             3.5  25.0
#
#                                         2025
#                            BRIDGE_LEAVE_RATE LONG_LEAVE_RATE 팀 인원수
# TEAM_NAME
# APAC Sales Team                         36.8             1.9  22.0
# Accounting Team                         40.9             2.0  11.0
# Analysis Team                           40.9             5.5  24.0
# Backend Team                            42.5             7.2  15.0
# Content Marketing Team                  42.4             7.6  19.0
# Domestic Sales Office                   43.8             0.6  13.0
# Domestic Sales Team 1                   40.9             2.2  22.0
# Domestic Sales Team 2                   40.9             1.2  18.0
# EU/NA Sales Team                        41.7             4.0  28.0
# Engineering Office                      25.2             4.8  26.0
# Finance Office                          39.1             0.9  26.0
# Frontend Team                           35.2             2.4  18.0
# Global Sales Office                     39.5             3.3  24.0
# HR Team                                 38.6             1.3  21.0
# Marketing Office                        39.5             9.9  17.0
# Mobile Team                             43.0             3.1  24.0
# Performance Marketing Team              35.0             1.3  18.0
# Planning Team                           35.8             2.3  26.0
# Process Engineering Team                27.3             0.8  27.0
# Production Office                       30.1             0.9  23.0
# Production Team Alpha                   32.0             0.0  19.0
# Production Team Beta                    30.0             0.0  16.0
# Production Team Charlie                 30.9             3.6  16.0
# QA Office                               35.9             0.0  14.0
# Quality Engineering Team                29.2             0.0  19.0
# R&D Office                              38.6             2.6  19.0
# Service QA Team                         42.2             2.5  20.0
# Strategy Office                         41.1             5.7  24.0
# System QA Team                          39.9             2.0  29.0
# Treasury Team                           38.8             0.9  23.0

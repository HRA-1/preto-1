# %%
# 2. 필요한 모듈 임포트
import pandas as pd
import plotly.io as pio
from IPython.display import display
import plotly.graph_objects as go

from src.services.data_preparer import prepare_proposal_05_data
from src.services.proposal_views.proposal_05_view import create_figure_and_df

# --- 테스트 실행 ---

# 1. app.py의 역할 (1): 데이터 준비 함수를 호출하여 필요한 데이터를 미리 로드합니다.
print("Step 1: `data_preparer`를 통해 분석용 데이터와 순서 정보를 준비합니다...")
data_bundle = prepare_proposal_05_data() # 글로벌 필터는 모두 기본값('전체')으로 호출
order_map = data_bundle.get("order_map", {})
print(" -> 데이터 준비 완료!")


# 2. app.py의 역할 (2): 사용자가 Streamlit 위젯을 통해 필터를 선택했다고 가정합니다.
# 이 값들을 바꾸면서 여러 경우를 테스트해볼 수 있습니다.

# 2-1. app.py에 있을 차원 설정(Dimension Config) 정의
DIMENSION_CONFIG = {
    '부서별': {'type': 'hierarchical', 'top': 'DIVISION_NAME', 'sub': 'OFFICE_NAME'},
    '직무별': {'type': 'hierarchical', 'top': 'JOB_L1_NAME', 'sub': 'JOB_L2_NAME'},
    '직위직급별': {'type': 'flat', 'col': 'POSITION_NAME'},
    '성별': {'type': 'flat', 'col': 'GENDER'},
    '연령별': {'type': 'flat', 'col': 'AGE_BIN'},
    '경력연차별': {'type': 'flat', 'col': 'CAREER_BIN'},
    '연봉구간별': {'type': 'flat', 'col': 'SALARY_BIN'},
    '지역별': {'type': 'flat', 'col': 'REGION_CATEGORY'},
    '계약별': {'type': 'flat', 'col': 'CONT_CATEGORY'}
}

# 2-2. 사용자 선택 시뮬레이션
# ----- 테스트하고 싶은 값으로 변경 -----
selected_dimension_ui = '직무별' # 예: '부서별', '직무별', '성별', '직위직급별'
drilldown_selection = '전체'   # '부서별' 선택 시 'Development Division' 등으로 변경 가능
# -----------------------------------

print(f"Step 2: 사용자가 '{selected_dimension_ui}' 차원을, '{drilldown_selection}' 그룹으로 보기를 선택했습니다.")


# 3. app.py의 역할 (3): view 함수에 준비된 모든 데이터와 필터 값을 전달하여 결과물 생성
print("Step 3: `view` 모듈을 호출하여 그래프와 요약 테이블을 생성합니다...")
# data_bundle에 데이터가 있는지 확인
if data_bundle.get("turnover_data") is not None and not data_bundle["turnover_data"].empty:
    fig, aggregate_df = create_figure_and_df(
        data_bundle=data_bundle, # view 함수가 data_bundle 전체를 받도록 수정
        dimension_ui_name=selected_dimension_ui, 
        drilldown_selection=drilldown_selection,
        dimension_config=DIMENSION_CONFIG,
        order_map=order_map
    )
    print(" -> 생성 완료!")
else:
    print(" -> 분석할 데이터가 없어 빈 결과물을 생성합니다.")
    fig, aggregate_df = go.Figure(), pd.DataFrame()


# --- 결과 확인 ---

# 4. ipynb에서 생성된 그래프를 확인합니다.
print("\n--- [결과 1] 생성된 Plotly 그래프 ---")
# pio.renderers.default = 'vscode' 
fig.show()

# 5. ipynb에서 생성된 요약 테이블(aggregate_df)을 확인합니다.
print(f"\n--- [결과 2] '{selected_dimension_ui}' 기준 생성된 요약 테이블 ---")
display(aggregate_df)
# Out:
# Step 1: `data_preparer`를 통해 분석용 데이터와 순서 정보를 준비합니다...
#  -> 데이터 준비 완료!
# Step 2: 사용자가 '직무별' 차원을, '전체' 그룹으로 보기를 선택했습니다.
# Step 3: `view` 모듈을 호출하여 그래프와 요약 테이블을 생성합니다...
#  -> 생성 완료!
#
# --- [결과 1] 생성된 Plotly 그래프 ---
# --- [결과 2] '직무별' 기준 생성된 요약 테이블 ---
# CATEGORY     전체     IT Management Support  Planning  Production & Engineering  \
# YEAR
# 2010       0.00   0.00                  -      0.00                      0.00
# 2011      12.08   8.45                0.0     12.63                     20.57
# 2012       7.49   4.44               60.0      3.93                      4.36
# 2013       4.10   2.53                0.0      2.41                      9.38
# 2014       6.73   5.93              12.63      7.27                      2.37
# 2015       6.91   6.44              18.56      4.44                      5.08
# 2016      11.22   7.73               6.28     13.48                      9.94
# 2017       8.63  10.33               9.23      3.64                      9.25
# 2018       9.08  11.98               7.12      6.34                     13.50
# 2019       9.24   8.50               18.4     11.49                      9.78
# 2020       8.34  11.18              11.21      5.58                      9.02
# 2021      11.20   6.61               6.38     13.33                     12.19
# 2022       8.73   6.16              11.06     10.91                      6.86
# 2023      11.79  12.86               7.44     12.24                      9.27
# 2024      12.41  11.63              13.26     14.20                      8.86
# 2025      14.97  10.92              15.45     13.69                     16.23
#
# CATEGORY  Sales & Marketing
# YEAR
# 2010                   0.00
# 2011                   7.55
# 2012                   6.45
# 2013                   4.17
# 2014                   8.44
# 2015                   8.58
# 2016                  14.90
# 2017                  11.11
# 2018                   6.21
# 2019                   4.82
# 2020                   7.19
# 2021                  13.78
# 2022                  10.07
# 2023                  13.98
# 2024                  14.38
# 2025                  18.34

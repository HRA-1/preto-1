# %%
# 2. 필요한 모듈 임포트
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
from IPython.display import display

from services.data_preparer import prepare_proposal_10_data
from services.proposal_views.proposal_10_view import create_figure_and_df

# --- 테스트 실행 ---

# 1. app.py의 역할 (1): 사용자가 선택한 '글로벌 필터'를 적용하여 데이터 준비 함수를 호출합니다.
print("Step 1: `data_preparer`를 통해 분석용 데이터와 순서 정보를 준비합니다...")

filtering = '남성' # prepare_proposal_07_data() 함수에 삽입
# 글로벌 필터는 모두 기본값('전체')으로 호출
# 예시: '부서별' 필터를 'Development Division'으로 설정하여 데이터 요청
data_bundle = prepare_proposal_10_data() 
analysis_df = data_bundle.get("analysis_df", pd.DataFrame())
order_map = data_bundle.get("order_map", {})
print(" -> 데이터 준비 완료!")


# 2. app.py의 역할 (2): view 함수 호출
# 이 view는 그래프 내에 자체 필터(드롭다운)가 있으므로, app.py에서는 추가적인 선택 시뮬레이션이 필요 없습니다.
print("Step 2: `view` 모듈을 호출하여 그래프와 요약 테이블을 생성합니다...")
if not analysis_df.empty:
    fig, aggregate_df = create_figure_and_df(
        analysis_df=analysis_df, 
        order_map=order_map 
    )
    print(" -> 생성 완료!")
else:
    print(" -> 분석할 데이터가 없어 빈 결과물을 생성합니다.")
    fig, aggregate_df = go.Figure(), pd.DataFrame()


# --- 결과 확인 ---

# 3. ipynb에서 생성된 그래프를 확인합니다.
# 그래프 상단의 '비교 기준' 드롭다운을 눌러 '학교 레벨별'과 '전공 계열별' 뷰를 전환해볼 수 있습니다.
print("\n--- [결과 1] 생성된 Plotly 그래프 ---")
# pio.renderers.default = 'vscode' 
fig.show()

# 4. ipynb에서 생성된 요약 테이블(aggregate_df)을 확인합니다.
# 이 테이블은 기본적으로 '학교 레벨별' 기준으로 생성됩니다.
print(f"\n--- [결과 2] 생성된 요약 테이블 ---")
display(aggregate_df)
# Out:
# 2025-10-14 07:49:49.370 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 07:49:49.371 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 07:49:49.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 07:49:49.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# Step 1: `data_preparer`를 통해 분석용 데이터와 순서 정보를 준비합니다...
# 2025-10-14 07:49:49.880 Thread 'Thread-9': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 07:49:49.886 Thread 'Thread-9': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-14 07:49:49.912 Thread 'Thread-9': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
